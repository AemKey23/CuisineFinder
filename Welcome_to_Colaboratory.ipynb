# %% [markdown]
# <a href="https://colab.research.google.com/github/AemKey23/CuisineFinder/blob/main/Welcome_to_Colaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h1>Welcome to Colab!</h1>
# </div>
#
# <!-- TODO(b/319266067) remove temporary advert after a few weeks. -->
# <div class="markdown-google-sans">
#   <h2>&#40;New&#41; Try the Gemini API</h2>
#   <ul>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Talk_to_Gemini_with_Google%27s_Speech_to_Text_API.ipynb?utm_medium=link&utm_campaign=gemini">Talk to Gemini with the Speech-to-Text API</a></li>
#   <li><a href="https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/Learning_with_Gemini_and_ChatGPT.ipynb?utm_medium=link&utm_campaign=gemini">Compare Gemini with ChatGPT</a></li>
#   <li><a href="https://colab.google/notebooks/?utm_medium=link&utm_campaign=gemini">More notebooks</a></li>
#   </ul>
# </div>

# %% [markdown]
# If you're already familiar with Colab, check out this video to learn about interactive tables, the executed code history view and the command palette.
#
# <center>
#   <a href="https://www.youtube.com/watch?v=rNgswRZ2C1Y" target="_blank">
#   <img alt='Thumbnail for a video showing three cool Google Colab features' src="data:image/png;base64,..." height="188" width="336">
#   </a>
# </center>

# %% [markdown]
# <div class="markdown-google-sans">
#   <h2>What is Colab?</h2>
# </div>
#
# Colab, or ‘Colaboratory’, allows you to write and execute Python in your browser, with
# - Zero configuration required
# - Access to GPUs free of charge
# - Easy sharing
#
# Whether you're a <strong>student</strong>, a <strong>data scientist</strong> or an <strong>AI researcher</strong>, Colab can make your work easier. Watch <a href="https://www.youtube.com/watch?v=inN8seMm7UI">Introduction to Colab</a> to find out more, or just get started below!

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## <strong>Getting started</strong>
# </div>
#
# The document that you are reading is not a static web page, but an interactive environment called a <strong>Colab notebook</strong> that lets you write and execute code.
#
# For example, here is a <strong>code cell</strong> with a short Python script that computes a value, stores it in a variable and prints the result:

# %%
seconds_in_a_day = 24 * 60 * 60
seconds_in_a_day
# Out:
# 86400

# %% [markdown]
# To execute the code in the above cell, select it with a click and then either press the play button to the left of the code, or use the keyboard shortcut 'Command/Ctrl+Enter'. To edit the code, just click the cell and start editing.
#
# Variables that you define in one cell can later be used in other cells:

# %%
seconds_in_a_week = 7 * seconds_in_a_day
seconds_in_a_week
# Out:
# 604800

# %% [markdown]
# Colab notebooks allow you to combine <strong>executable code</strong> and <strong>rich text</strong> in a single document, along with <strong>images</strong>, <strong>HTML</strong>, <strong>LaTeX</strong> and more. When you create your own Colab notebooks, they are stored in your Google Drive account. You can easily share your Colab notebooks with co-workers or friends, allowing them to comment on your notebooks or even edit them. To find out more, see <a href="/notebooks/basic_features_overview.ipynb">Overview of Colab</a>. To create a new Colab notebook you can use the File menu above, or use the following link: <a href="http://colab.research.google.com#create=true">Create a new Colab notebook</a>.
#
# Colab notebooks are Jupyter notebooks that are hosted by Colab. To find out more about the Jupyter project, see <a href="https://www.jupyter.org">jupyter.org</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Data science
# </div>
#
# With Colab you can harness the full power of popular Python libraries to analyse and visualise data. The code cell below uses <strong>numpy</strong> to generate some random data, and uses <strong>matplotlib</strong> to visualise it. To edit the code, just click the cell and start editing.

# %%
import numpy as np
from matplotlib import pyplot as plt

ys = 200 + np.random.randn(100)
x = [x for x in range(len(ys))]

plt.plot(x, ys, '-')
plt.fill_between(x, ys, 195, where=(ys > 195), facecolor='g', alpha=0.6)

plt.title("Sample Visualization")
plt.show()

# %% [markdown]
# You can import your own data into Colab notebooks from your Google Drive account, including from spreadsheets, as well as from GitHub and many other sources. To find out more about importing data, and how Colab can be used for data science, see the links below under <a href="#working-with-data">Working with data</a>.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## Machine learning
# </div>
#
# With Colab you can import an image dataset, train an image classifier on it, and evaluate the model, all in just <a href="https://colab.research.google.com/github/tensorflow/docs/blob/master/site/en/tutorials/quickstart/beginner.ipynb">a few lines of code</a>. Colab notebooks execute code on Google's cloud servers, meaning you can leverage the power of Google hardware, including <a href="#using-accelerated-hardware">GPUs and TPUs</a>, regardless of the power of your machine. All you need is a browser.

# %% [markdown]
# Colab is used extensively in the machine learning community with applications including:
# - Getting started with TensorFlow
# - Developing and training neural networks
# - Experimenting with TPUs
# - Disseminating AI research
# - Creating tutorials
#
# To see sample Colab notebooks that demonstrate machine learning applications, see the <a href="#machine-learning-examples">machine learning examples</a> below.

# %% [markdown]
# <div class="markdown-google-sans">
#
# ## More resources
#
# ### Working with notebooks in Colab
#
# </div>
#
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to markdown](/notebooks/markdown_guide.ipynb)
# - [Importing libraries and installing dependencies](/notebooks/snippets/importing_libraries.ipynb)
# - [Saving and loading notebooks in GitHub](https://colab.research.google.com/github/googlecolab/colabtools/blob/main/notebooks/colab-github-demo.ipynb)
# - [Interactive forms](/notebooks/forms.ipynb)
# - [Interactive widgets](/notebooks/widgets.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="working-with-data"></a>
# ### Working with data
# </div>
#
# - [Loading data: Drive, Sheets and Google Cloud Storage](/notebooks/io.ipynb)
# - [Charts: visualising data](/notebooks/charts.ipynb)
# - [Getting started with BigQuery](/notebooks/bigquery.ipynb)
#
# <div class="markdown-google-sans">
#
# ### Machine learning crash course
#
# <div>
#
# These are a few of the notebooks from Google's online machine learning course. See the <a href="https://developers.google.com/machine-learning/crash-course/">full course website</a> for more.
# - [Intro to Pandas DataFrame](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/pandas_dataframe_ultraquick_tutorial.ipynb)
# - [Linear regression with tf.keras using synthetic data](https://colab.research.google.com/github/google/eng-edu/blob/main/ml/cc/exercises/linear_regression_with_synthetic_data.ipynb)
#
# <div class="markdown-google-sans">
#
# <a name="using-accelerated-hardware"></a>
# ### Using accelerated hardware
# </div>
#
# - [TensorFlow with GPUs](/notebooks/gpu.ipynb)
# - [TensorFlow with TPUs](/notebooks/tpu.ipynb)

# %% [markdown]
# <div class="markdown-google-sans">
#
# <a name="machine-learning-examples"></a>
#
# ### Featured examples
#
# </div>
#
# - <a href="https://colab.research.google.com/github/NVIDIA/NeMo/blob/stable/tutorials/VoiceSwapSample.ipynb">NeMo voice swap</a>: Use Nvidia NeMo conversational AI toolkit to swap a voice in an audio fragment with a computer-generated one.
#
# - <a href="https://tensorflow.org/hub/tutorials/tf2_image_retraining">Retraining an Image Classifier</a>: Build a Keras model on top of a pre-trained image classifier to distinguish flowers.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_text_classification">Text Classification</a>: Classify IMDB film reviews as either <em>positive</em> or <em>negative</em>.
# - <a href="https://tensorflow.org/hub/tutorials/tf2_arbitrary_image_stylization">Style Transfer</a>: Use deep learning to transfer style between images.
# - <a href="https://tensorflow.org/hub/tutorials/retrieval_with_tf_hub_universal_encoder_qa">Multilingual Universal Sentence Encoder Q&amp;A</a>: Use a machine-learning model to answer questions from the SQuAD dataset.
# - <a href="https://tensorflow.org/hub/tutorials/tweening_conv3d">Video Interpolation</a>: Predict what happened in a video between the first and the last frame.

# %%
# !pip install -q -U google-generativeai

# %%
import pathlib

# %%
import textwrap
import google.generativeai as genai

from google.colab import userdata
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
  text = text.replace('.', ' *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
import os
os.environ['GOOGLE_API_KEY']="AIzaSyCOPZwW2KPTNpYXdyifH7MQZsosK3itw_0"

# %%
genai.configure(api_key=os.environ['GOOGLE_API_KEY'])

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-pro
# models/gemini-pro-vision

# %%
model = genai.GenerativeModel('gemini-pro')

# %%
model
# Out:
#  genai.GenerativeModel(
#    model_name='models/gemini-pro',
#    generation_config={}.
#    safety_settings={}
# )

# %%
# %%time
response = model.generate_content("What do you think about china?", stream=True)
# Out:
# CPU times: user 131 ms, sys: 16.8 ms, total: 148 ms
# Wall time: 10.3 s

# %%
for chunk in response:
  print(chunk.text)
# Out:
# China is a vast and diverse country with a rich history and culture. It is
#  the world's most populous country, with over 1.4 billion people, and is also the second-largest economy in the world. China has a
#  long and complex history, dating back thousands of years, and has been a major player in world affairs for centuries.
#
# In recent years, China has undergone a period of rapid economic growth and development. This has led to a number of changes in the country, including a growing middle class, increased urbanization, and a more
#  open and globalized economy. China is now a major player in the global economy and is expected to continue to grow in importance in the years to come.
#
# China is a fascinating and complex country with a rich history and culture. It is a country that is constantly changing and evolving, and it is sure to continue to play a major role in world affairs for many years to come.
#
# Here are some of the things that make China unique:
#
# * **Its size and population:** China is the world's most populous country, with over 1.4 billion people. It is also the second-largest country in the world by
#  land area, after Russia.
# * **Its history:** China has a long and complex history, dating back thousands of years. It has been a major player in world affairs for centuries and has been home to some of the world's most famous civilizations.
# * **Its culture:** China has a rich and diverse culture. It is home to a wide variety of ethnic groups, each with its own unique customs and traditions. China is also known for its cuisine, which is one of the most popular in the world.
# * **Its economy:** China is the world's second-largest economy and is expected to continue to grow in importance in the years to come. The country has undergone a period of rapid economic growth and development in recent years, which has led to a number of changes in the country, including a growing middle class, increased urbanization, and a more open and globalized economy.
# * **Its role in world affairs:** China is a major player in world affairs and is expected to continue to play a more important role in the years to come. The country is a permanent member of the United Nations Security Council and is also a member of the G20. China is also a major trading partner for many countries around the world.
#
# China is
#  a fascinating and complex country with a rich history and culture. It is a country that is constantly changing and evolving, and it is sure to continue to play a major role in world affairs for many years to come.

# %%
to_markdown(response.text)
# Out:
# > China is a complex and diverse country with a long and rich history * It is the most populous country in the world, with over 1 *4 billion people, and it is also the second largest economy in the world * China has a rich culture and history, and it is home to some of the world's most iconic landmarks, such as the Great Wall of China and the Forbidden City *
# >
# > China has undergone a significant transformation in recent decades, moving from a closed, centrally planned economy to a more open, market-oriented economy * This has led to rapid economic growth and a significant improvement in the standard of living for many Chinese people * However, China still faces a number of challenges, including environmental pollution, income inequality, and corruption *
# >
# > China plays an important role in the global economy and is a major player in international affairs * It is a permanent member of the United Nations Security Council and is also a member of the World Trade Organization * China has also become a major investor in other countries, and its economic and political influence is growing rapidly *
# >
# > China is a country with a long and complex history, and it is a major player in the global economy and international affairs * It is a country with great potential, but it also faces a number of challenges * How China develops in the future will have a significant impact on the world *
# >
# > Here are some additional thoughts on China:
# >
# > * China has a long and rich history, dating back to the Xia Dynasty in the 21st century BC *
# > * China is home to a diverse population, with 56 ethnic groups recognized by the government *
# > * China has a rich culture and tradition, with a wide variety of art, music, and cuisine *
# > * China is a major economic powerhouse, and is the second largest economy in the world *
# > * China is a major player in international affairs, and is a permanent member of the United Nations Security Council *
# > * China faces a number of challenges, including environmental pollution, income inequality, and corruption *
# > * China's future development will have a significant impact on the world *

# %%
import PIL.Image
img= PIL.Image.open('baahubali.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=810x450>

# %%
model = genai.GenerativeModel('gemini-pro-vision')
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# >  The picture shows two people walking away from an explosion * The one in front is pulling the other, who is injured *

# %%
response = model.generate_content(["who are two charactors in this image, there was one question that came into mind of people, what was that? do research about movie before giving an answer context:baahubali movie", img])
response.resolve()
to_markdown(response.text)
# Out:
# >  The two characters in this image are Baahubali and Bhallaladeva from the movie Baahubali * The question that came into mind of people was, "Who is the real hero of the movie?" There are two main characters in the movie, Baahubali and Bhallaladeva * Baahubali is the son of the king, while Bhallaladeva is his cousin * Bhallaladeva is jealous of Baahubali and wants to kill him * He tricks Baahubali into fighting a war against him, and Baahubali is killed * However, Baahubali's son, Mahendra, survives and grows up to avenge his father's death * Mahendra defeats Bhallaladeva and becomes the king *
